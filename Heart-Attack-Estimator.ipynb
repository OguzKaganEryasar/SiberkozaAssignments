# %%
import pandas as pd
df = pd.read_csv ('heart.csv')
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df.shape
# Out:
# (303, 14)

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %%
import pandas as pd
client_data = pd.read_csv ('heart.csv')
client_data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
import pandas as pd
client_data = pd.read_csv ('heart.csv')
X = client_data.drop(columns=['output'])
X
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall
# 0      0      1
# 1      0      2
# ...

# %%
import pandas as pd
client_data = pd.read_csv ('heart.csv')
X = client_data.drop(columns=['output'])
y = client_data['output']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: output, Length: 303, dtype: int64

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

client_data = pd.read_csv ('heart.csv')
X = client_data.drop(columns=['output'])
y = client_data['output']

model = DecisionTreeClassifier()
model.fit(X, y)
client_data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

client_data = pd.read_csv ('heart.csv')
X = client_data.drop(columns=['output'])
y = client_data['output']

model = DecisionTreeClassifier()
model.fit(X, y)
predictions = model.predict([[60,1,3,140,233,1,0,150,0,2.5,0,0,1]])
predictions
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

client_data = pd.read_csv ('heart.csv')
X = client_data.drop(columns=['output'])
y = client_data['output']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
score = accuracy_score(y_test, predictions)
score
# Out:
# 0.7868852459016393

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.externals import joblib

client_data = pd.read_csv ('heart.csv')
X = client_data.drop(columns=['output'])
y = client_data['output']

model = DecisionTreeClassifier()
model.fit(X, y)

joblib.dump(model,'heart-attack-estimator.joblib')

#predictions = model.predict([[60,1,3,140,233,1,0,150,0,2.5,0,0,1]])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24800\2782839897.py in <module>
#       1 import pandas as pd
#       2 from sklearn.tree import DecisionTreeClassifier
# ----> 3 from sklearn.externals import joblib
#       4
#       5 client_data = pd.read_csv ('heart.csv')
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (C:\Users\pc\anaconda3\lib\site-packages\sklearn\externals\__init__.py)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.externals import joblib

#client_data = pd.read_csv ('heart.csv')
#X = client_data.drop(columns=['output'])
#y = client_data['output']

#model = DecisionTreeClassifier()
#model.fit(X, y)

model = joblib.load(model,'heart-attack-estimator.joblib')
predictions = model.predict([[60,1,3,140,233,1,0,150,0,2.5,0,0,1]])
predictions
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24800\2090886951.py in <module>
#       1 import pandas as pd
#       2 from sklearn.tree import DecisionTreeClassifier
# ----> 3 from sklearn.externals import joblib
#       4
#       5 #client_data = pd.read_csv ('heart.csv')
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (C:\Users\pc\anaconda3\lib\site-packages\sklearn\externals\__init__.py)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

client_data = pd.read_csv ('heart.csv')
X = client_data.drop(columns=['output'])
y = client_data['output']

model = DecisionTreeClassifier()
model.fit(X, y)
tree.export_graphviz(model, out_file='heart-attack-estimator.dot', 
                     feature_names=['age','sex','cp','trtbps','chol','fbs','restecg','thalachh','exng','oldpeak','slp','caa','thall'],
                     class_names=sorted(y.unique()),
                     label='all',
                     rounded = True,
                     filled = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24800\3645080871.py in <module>
#       9 model = DecisionTreeClassifier()
#      10 model.fit(X, y)
# ---> 11 tree.export_graphviz(model, out_file='heart-attack-estimator.dot',
#      12                      feature_names=['age','sex','cp','trtbps','chol','fbs','restecg','thalachh','exng','oldpeak','slp','caa','thall'],
#      13                      class_names=sorted(y.unique()),
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     887             fontname=fontname,
#     888         )
# --> 889         exporter.export(decision_tree)
#     890
#     891         if return_string:
#
# ...
